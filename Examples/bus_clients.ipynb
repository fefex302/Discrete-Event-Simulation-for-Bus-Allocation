# %%
# !pip install --upgrade simpy
# Out:
# Requirement already satisfied: simpy in c:\users\fede\desktop\cmcs project\discrete-event-simulation-for-bus-allocation\venvsimpy\lib\site-packages (4.1.1)
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Voglio modellare un solo pullman con 10 posti e clienti che arrivano ogni 1 tu.
#
# 1) Il bus è in attesa e appena salgono 10 cienti parte.
# 2) impiega 12 tu ad andare/scaricare e tornare.
# 3) Carica altri 10 clienti e riparte.

# %%
import simpy

# %%
class Bus(object):
    def __init__(self, env, bus_capacity, travel_time=12):
        self.env = env
        self.travel_time = travel_time
        self.seats = simpy.Container(env, capacity=bus_capacity, init=0)
        self.departure_event = env.event()
        self.arrival = env.event()
        self.action = env.process(self.run())

    def run(self):
        while True:
            print(f'{self.env.now:.2f}: Bus alla fermata in attesa del segnale di partenza.')
            
            # 1. ATTENDI IL SEGNALE
            yield self.departure_event
            
            # 2. PARTI E VIAGGIA
            print(f'{self.env.now:.2f}: Segnale ricevuto! Bus parte con {self.seats.level} passeggeri.')

            # Dopo metà del tempo di viaggio, il bus arriva a destinazione
            # e segnala il suo arrivo.
            yield self.env.timeout(self.travel_time/2)
            self.arrival.succeed()

            # Viaggio di ritorno
            yield self.env.timeout(self.travel_time/2)

            # 3. TORNA E SVUOTA I POSTI
            print(f'{self.env.now:.2f}: Bus tornato.')
            yield self.seats.get(self.seats.capacity)
            # segnala che il bus è tornato e 
            
            # 4. PREPARA IL PROSSIMO CICLO
            self.arrival = self.env.event()
            self.departure_event = self.env.event()

# %%
env = simpy.Environment()
# Create a bus with a capacity of 10 passengers
bus = Bus(env,10)

# %%
# --- Processo Passeggero (con controllo di sicurezza sull'evento) ---
def passeggero(env, nome, bus, attese):
    print(f'{env.now:.2f}: Il passeggero {nome} arriva alla fermata.')
    arrivo = env.now
    yield bus.seats.put(1)
    salito = env.now
    print(f'{env.now:.2f}: Il passeggero {nome} è salito. Posti occupati: {bus.seats.level}')
    
    # Se il bus è pieno E l'evento di partenza non è già stato attivato...
    if bus.seats.level == bus.seats.capacity and not bus.departure_event.triggered:
        # ...allora attiva l'evento.
        print(f'{env.now:.2f}: Bus pieno! Il passeggero {nome} segnala la partenza.')
        bus.departure_event.succeed()
    yield bus.arrival  # Attendi l'arrivo del bus
    discesa = env.now
    attesa = discesa - arrivo
    attese.append(attesa)

# --- Processo Generatore di Passeggeri (invariato) ---
def arrivi_passeggeri(env, bus, attese):
    contatore_passeggeri = 0
    while True:
        yield env.timeout(1)
        contatore_passeggeri += 1
        env.process(passeggero(env, f'P{contatore_passeggeri}', bus, attese))

# %%
attese = []
passenger_arrival_process = env.process(arrivi_passeggeri(env, bus, attese))
env.run(until=200)  # Run the simulation for 50 time units
# Out:
# 0.00: Bus alla fermata in attesa del segnale di partenza.
# 1.00: Il passeggero P1 arriva alla fermata.
# 1.00: Il passeggero P1 è salito. Posti occupati: 1
# 2.00: Il passeggero P2 arriva alla fermata.
# 2.00: Il passeggero P2 è salito. Posti occupati: 2
# 3.00: Il passeggero P3 arriva alla fermata.
# 3.00: Il passeggero P3 è salito. Posti occupati: 3
# 4.00: Il passeggero P4 arriva alla fermata.
# 4.00: Il passeggero P4 è salito. Posti occupati: 4
# 5.00: Il passeggero P5 arriva alla fermata.
# 5.00: Il passeggero P5 è salito. Posti occupati: 5
# 6.00: Il passeggero P6 arriva alla fermata.
# 6.00: Il passeggero P6 è salito. Posti occupati: 6
# 7.00: Il passeggero P7 arriva alla fermata.
# 7.00: Il passeggero P7 è salito. Posti occupati: 7
# 8.00: Il passeggero P8 arriva alla fermata.
# 8.00: Il passeggero P8 è salito. Posti occupati: 8
# 9.00: Il passeggero P9 arriva alla fermata.
# 9.00: Il passeggero P9 è salito. Posti occupati: 9
# 10.00: Il passeggero P10 arriva alla fermata.
# 10.00: Il passeggero P10 è salito. Posti occupati: 10
# 10.00: Bus pieno! Il passeggero P10 segnala la partenza.
# 10.00: Segnale ricevuto! Bus parte con 10 passeggeri.
# 11.00: Il passeggero P11 arriva alla fermata.
# 12.00: Il passeggero P12 arriva alla fermata.
# 13.00: Il passeggero P13 arriva alla fermata.
# 14.00: Il passeggero P14 arriva alla fermata.
# 15.00: Il passeggero P15 arriva alla fermata.
# 16.00: Il passeggero P16 arriva alla fermata.
# 17.00: Il passeggero P17 arriva alla fermata.
# 18.00: Il passeggero P18 arriva alla fermata.
# 19.00: Il passeggero P19 arriva alla fermata.
# 20.00: Il passeggero P20 arriva alla fermata.
# 21.00: Il passeggero P21 arriva alla fermata.
# 22.00: Bus tornato.
# 22.00: Il passeggero P22 arriva alla fermata.
# 22.00: Bus alla fermata in attesa del segnale di partenza.
# 22.00: Il passeggero P11 è salito. Posti occupati: 10
# 22.00: Bus pieno! Il passeggero P11 segnala la partenza.
# 22.00: Il passeggero P12 è salito. Posti occupati: 10
# 22.00: Il passeggero P13 è salito. Posti occupati: 10
# 22.00: Il passeggero P14 è salito. Posti occupati: 10
# 22.00: Il passeggero P15 è salito. Posti occupati: 10
# 22.00: Il passeggero P16 è salito. Posti occupati: 10
# 22.00: Il passeggero P17 è salito. Posti occupati: 10
# 22.00: Il passeggero P18 è salito. Posti occupati: 10
# 22.00: Il passeggero P19 è salito. Posti occupati: 10
# 22.00: Il passeggero P20 è salito. Posti occupati: 10
# 22.00: Segnale ricevuto! Bus parte con 10 passeggeri.
# 23.00: Il passeggero P23 arriva alla fermata.
# 24.00: Il passeggero P24 arriva alla fermata.
# 25.00: Il passeggero P25 arriva alla fermata.
# 26.00: Il passeggero P26 arriva alla fermata.
# 27.00: Il passeggero P27 arriva alla fermata.
# 28.00: Il passeggero P28 arriva alla fermata.
# 29.00: Il passeggero P29 arriva alla fermata.
# 30.00: Il passeggero P30 arriva alla fermata.
# 31.00: Il passeggero P31 arriva alla fermata.
# 32.00: Il passeggero P32 arriva alla fermata.
# 33.00: Il passeggero P33 arriva alla fermata.
# 34.00: Bus tornato.
# 34.00: Il passeggero P34 arriva alla fermata.
# 34.00: Bus alla fermata in attesa del segnale di partenza.
# 34.00: Il passeggero P21 è salito. Posti occupati: 10
# 34.00: Bus pieno! Il passeggero P21 segnala la partenza.
# 34.00: Il passeggero P22 è salito. Posti occupati: 10
# 34.00: Il passeggero P23 è salito. Posti occupati: 10
# 34.00: Il passeggero P24 è salito. Posti occupati: 10
# 34.00: Il passeggero P25 è salito. Posti occupati: 10
# 34.00: Il passeggero P26 è salito. Posti occupati: 10
# 34.00: Il passeggero P27 è salito. Posti occupati: 10
# 34.00: Il passeggero P28 è salito. Posti occupati: 10
# 34.00: Il passeggero P29 è salito. Posti occupati: 10
# 34.00: Il passeggero P30 è salito. Posti occupati: 10
# 34.00: Segnale ricevuto! Bus parte con 10 passeggeri.
# 35.00: Il passeggero P35 arriva alla fermata.
# 36.00: Il passeggero P36 arriva alla fermata.
# 37.00: Il passeggero P37 arriva alla fermata.
# 38.00: Il passeggero P38 arriva alla fermata.
# 39.00: Il passeggero P39 arriva alla fermata.
# 40.00: Il passeggero P40 arriva alla fermata.
# 41.00: Il passeggero P41 arriva alla fermata.
# 42.00: Il passeggero P42 arriva alla fermata.
# 43.00: Il passeggero P43 arriva alla fermata.
# 44.00: Il passeggero P44 arriva alla fermata.
# 45.00: Il passeggero P45 arriva alla fermata.
# 46.00: Bus tornato.
# 46.00: Il passeggero P46 arriva alla fermata.
# 46.00: Bus alla fermata in attesa del segnale di partenza.
# 46.00: Il passeggero P31 è salito. Posti occupati: 10
# 46.00: Bus pieno! Il passeggero P31 segnala la partenza.
# 46.00: Il passeggero P32 è salito. Posti occupati: 10
# 46.00: Il passeggero P33 è salito. Posti occupati: 10
# 46.00: Il passeggero P34 è salito. Posti occupati: 10
# 46.00: Il passeggero P35 è salito. Posti occupati: 10
# 46.00: Il passeggero P36 è salito. Posti occupati: 10
# 46.00: Il passeggero P37 è salito. Posti occupati: 10
# 46.00: Il passeggero P38 è salito. Posti occupati: 10
# 46.00: Il passeggero P39 è salito. Posti occupati: 10
# 46.00: Il passeggero P40 è salito. Posti occupati: 10
# 46.00: Segnale ricevuto! Bus parte con 10 passeggeri.
# 47.00: Il passeggero P47 arriva alla fermata.
# 48.00: Il passeggero P48 arriva alla fermata.
# 49.00: Il passeggero P49 arriva alla fermata.
# 50.00: Il passeggero P50 arriva alla fermata.
# 51.00: Il passeggero P51 arriva alla fermata.
# 52.00: Il passeggero P52 arriva alla fermata.
# 53.00: Il passeggero P53 arriva alla fermata.
# 54.00: Il passeggero P54 arriva alla fermata.
# 55.00: Il passeggero P55 arriva alla fermata.
# 56.00: Il passeggero P56 arriva alla fermata.
# 57.00: Il passeggero P57 arriva alla fermata.
# 58.00: Bus tornato.
# 58.00: Il passeggero P58 arriva alla fermata.
# 58.00: Bus alla fermata in attesa del segnale di partenza.
# 58.00: Il passeggero P41 è salito. Posti occupati: 10
# 58.00: Bus pieno! Il passeggero P41 segnala la partenza.
# 58.00: Il passeggero P42 è salito. Posti occupati: 10
# 58.00: Il passeggero P43 è salito. Posti occupati: 10
# 58.00: Il passeggero P44 è salito. Posti occupati: 10
# 58.00: Il passeggero P45 è salito. Posti occupati: 10
# 58.00: Il passeggero P46 è salito. Posti occupati: 10
# 58.00: Il passeggero P47 è salito. Posti occupati: 10
# 58.00: Il passeggero P48 è salito. Posti occupati: 10
# 58.00: Il passeggero P49 è salito. Posti occupati: 10
# 58.00: Il passeggero P50 è salito. Posti occupati: 10
# 58.00: Segnale ricevuto! Bus parte con 10 passeggeri.
# 59.00: Il passeggero P59 arriva alla fermata.
# 60.00: Il passeggero P60 arriva alla fermata.
# 61.00: Il passeggero P61 arriva alla fermata.
# 62.00: Il passeggero P62 arriva alla fermata.
# 63.00: Il passeggero P63 arriva alla fermata.
# 64.00: Il passeggero P64 arriva alla fermata.
# 65.00: Il passeggero P65 arriva alla fermata.
# 66.00: Il passeggero P66 arriva alla fermata.
# 67.00: Il passeggero P67 arriva alla fermata.
# 68.00: Il passeggero P68 arriva alla fermata.
# 69.00: Il passeggero P69 arriva alla fermata.
# 70.00: Bus tornato.
# 70.00: Il passeggero P70 arriva alla fermata.
# 70.00: Bus alla fermata in attesa del segnale di partenza.
# 70.00: Il passeggero P51 è salito. Posti occupati: 10
# 70.00: Bus pieno! Il passeggero P51 segnala la partenza.
# 70.00: Il passeggero P52 è salito. Posti occupati: 10
# 70.00: Il passeggero P53 è salito. Posti occupati: 10
# 70.00: Il passeggero P54 è salito. Posti occupati: 10
# 70.00: Il passeggero P55 è salito. Posti occupati: 10
# 70.00: Il passeggero P56 è salito. Posti occupati: 10
# 70.00: Il passeggero P57 è salito. Posti occupati: 10
# 70.00: Il passeggero P58 è salito. Posti occupati: 10
# 70.00: Il passeggero P59 è salito. Posti occupati: 10
# 70.00: Il passeggero P60 è salito. Posti occupati: 10
# 70.00: Segnale ricevuto! Bus parte con 10 passeggeri.
# 71.00: Il passeggero P71 arriva alla fermata.
# 72.00: Il passeggero P72 arriva alla fermata.
# 73.00: Il passeggero P73 arriva alla fermata.
# 74.00: Il passeggero P74 arriva alla fermata.
# 75.00: Il passeggero P75 arriva alla fermata.
# 76.00: Il passeggero P76 arriva alla fermata.
# 77.00: Il passeggero P77 arriva alla fermata.
# 78.00: Il passeggero P78 arriva alla fermata.
# 79.00: Il passeggero P79 arriva alla fermata.
# 80.00: Il passeggero P80 arriva alla fermata.
# 81.00: Il passeggero P81 arriva alla fermata.
# 82.00: Bus tornato.
# 82.00: Il passeggero P82 arriva alla fermata.
# 82.00: Bus alla fermata in attesa del segnale di partenza.
# 82.00: Il passeggero P61 è salito. Posti occupati: 10
# 82.00: Bus pieno! Il passeggero P61 segnala la partenza.
# 82.00: Il passeggero P62 è salito. Posti occupati: 10
# 82.00: Il passeggero P63 è salito. Posti occupati: 10
# 82.00: Il passeggero P64 è salito. Posti occupati: 10
# 82.00: Il passeggero P65 è salito. Posti occupati: 10
# 82.00: Il passeggero P66 è salito. Posti occupati: 10
# 82.00: Il passeggero P67 è salito. Posti occupati: 10
# 82.00: Il passeggero P68 è salito. Posti occupati: 10
# 82.00: Il passeggero P69 è salito. Posti occupati: 10
# 82.00: Il passeggero P70 è salito. Posti occupati: 10
# 82.00: Segnale ricevuto! Bus parte con 10 passeggeri.
# 83.00: Il passeggero P83 arriva alla fermata.
# 84.00: Il passeggero P84 arriva alla fermata.
# 85.00: Il passeggero P85 arriva alla fermata.
# 86.00: Il passeggero P86 arriva alla fermata.
# 87.00: Il passeggero P87 arriva alla fermata.
# 88.00: Il passeggero P88 arriva alla fermata.
# 89.00: Il passeggero P89 arriva alla fermata.
# 90.00: Il passeggero P90 arriva alla fermata.
# 91.00: Il passeggero P91 arriva alla fermata.
# 92.00: Il passeggero P92 arriva alla fermata.
# 93.00: Il passeggero P93 arriva alla fermata.
# 94.00: Bus tornato.
# 94.00: Il passeggero P94 arriva alla fermata.
# 94.00: Bus alla fermata in attesa del segnale di partenza.
# 94.00: Il passeggero P71 è salito. Posti occupati: 10
# 94.00: Bus pieno! Il passeggero P71 segnala la partenza.
# 94.00: Il passeggero P72 è salito. Posti occupati: 10
# 94.00: Il passeggero P73 è salito. Posti occupati: 10
# 94.00: Il passeggero P74 è salito. Posti occupati: 10
# 94.00: Il passeggero P75 è salito. Posti occupati: 10
# 94.00: Il passeggero P76 è salito. Posti occupati: 10
# 94.00: Il passeggero P77 è salito. Posti occupati: 10
# 94.00: Il passeggero P78 è salito. Posti occupati: 10
# 94.00: Il passeggero P79 è salito. Posti occupati: 10
# 94.00: Il passeggero P80 è salito. Posti occupati: 10
# 94.00: Segnale ricevuto! Bus parte con 10 passeggeri.
# 95.00: Il passeggero P95 arriva alla fermata.
# 96.00: Il passeggero P96 arriva alla fermata.
# 97.00: Il passeggero P97 arriva alla fermata.
# 98.00: Il passeggero P98 arriva alla fermata.
# 99.00: Il passeggero P99 arriva alla fermata.
# 100.00: Il passeggero P100 arriva alla fermata.
# 101.00: Il passeggero P101 arriva alla fermata.
# 102.00: Il passeggero P102 arriva alla fermata.
# 103.00: Il passeggero P103 arriva alla fermata.
# 104.00: Il passeggero P104 arriva alla fermata.
# 105.00: Il passeggero P105 arriva alla fermata.
# 106.00: Bus tornato.
# 106.00: Il passeggero P106 arriva alla fermata.
# 106.00: Bus alla fermata in attesa del segnale di partenza.
# 106.00: Il passeggero P81 è salito. Posti occupati: 10
# 106.00: Bus pieno! Il passeggero P81 segnala la partenza.
# 106.00: Il passeggero P82 è salito. Posti occupati: 10
# 106.00: Il passeggero P83 è salito. Posti occupati: 10
# 106.00: Il passeggero P84 è salito. Posti occupati: 10
# 106.00: Il passeggero P85 è salito. Posti occupati: 10
# 106.00: Il passeggero P86 è salito. Posti occupati: 10
# 106.00: Il passeggero P87 è salito. Posti occupati: 10
# 106.00: Il passeggero P88 è salito. Posti occupati: 10
# 106.00: Il passeggero P89 è salito. Posti occupati: 10
# 106.00: Il passeggero P90 è salito. Posti occupati: 10
# 106.00: Segnale ricevuto! Bus parte con 10 passeggeri.
# 107.00: Il passeggero P107 arriva alla fermata.
# 108.00: Il passeggero P108 arriva alla fermata.
# 109.00: Il passeggero P109 arriva alla fermata.
# 110.00: Il passeggero P110 arriva alla fermata.
# 111.00: Il passeggero P111 arriva alla fermata.
# 112.00: Il passeggero P112 arriva alla fermata.
# 113.00: Il passeggero P113 arriva alla fermata.
# 114.00: Il passeggero P114 arriva alla fermata.
# 115.00: Il passeggero P115 arriva alla fermata.
# 116.00: Il passeggero P116 arriva alla fermata.
# 117.00: Il passeggero P117 arriva alla fermata.
# 118.00: Bus tornato.
# 118.00: Il passeggero P118 arriva alla fermata.
# 118.00: Bus alla fermata in attesa del segnale di partenza.
# 118.00: Il passeggero P91 è salito. Posti occupati: 10
# 118.00: Bus pieno! Il passeggero P91 segnala la partenza.
# 118.00: Il passeggero P92 è salito. Posti occupati: 10
# 118.00: Il passeggero P93 è salito. Posti occupati: 10
# 118.00: Il passeggero P94 è salito. Posti occupati: 10
# 118.00: Il passeggero P95 è salito. Posti occupati: 10
# 118.00: Il passeggero P96 è salito. Posti occupati: 10
# 118.00: Il passeggero P97 è salito. Posti occupati: 10
# 118.00: Il passeggero P98 è salito. Posti occupati: 10
# 118.00: Il passeggero P99 è salito. Posti occupati: 10
# 118.00: Il passeggero P100 è salito. Posti occupati: 10
# 118.00: Segnale ricevuto! Bus parte con 10 passeggeri.
# 119.00: Il passeggero P119 arriva alla fermata.
# 120.00: Il passeggero P120 arriva alla fermata.
# 121.00: Il passeggero P121 arriva alla fermata.
# 122.00: Il passeggero P122 arriva alla fermata.
# 123.00: Il passeggero P123 arriva alla fermata.
# 124.00: Il passeggero P124 arriva alla fermata.
# 125.00: Il passeggero P125 arriva alla fermata.
# 126.00: Il passeggero P126 arriva alla fermata.
# 127.00: Il passeggero P127 arriva alla fermata.
# 128.00: Il passeggero P128 arriva alla fermata.
# 129.00: Il passeggero P129 arriva alla fermata.
# 130.00: Bus tornato.
# 130.00: Il passeggero P130 arriva alla fermata.
# 130.00: Bus alla fermata in attesa del segnale di partenza.
# 130.00: Il passeggero P101 è salito. Posti occupati: 10
# 130.00: Bus pieno! Il passeggero P101 segnala la partenza.
# 130.00: Il passeggero P102 è salito. Posti occupati: 10
# 130.00: Il passeggero P103 è salito. Posti occupati: 10
# 130.00: Il passeggero P104 è salito. Posti occupati: 10
# 130.00: Il passeggero P105 è salito. Posti occupati: 10
# 130.00: Il passeggero P106 è salito. Posti occupati: 10
# 130.00: Il passeggero P107 è salito. Posti occupati: 10
# 130.00: Il passeggero P108 è salito. Posti occupati: 10
# 130.00: Il passeggero P109 è salito. Posti occupati: 10
# 130.00: Il passeggero P110 è salito. Posti occupati: 10
# 130.00: Segnale ricevuto! Bus parte con 10 passeggeri.
# 131.00: Il passeggero P131 arriva alla fermata.
# 132.00: Il passeggero P132 arriva alla fermata.
# 133.00: Il passeggero P133 arriva alla fermata.
# 134.00: Il passeggero P134 arriva alla fermata.
# 135.00: Il passeggero P135 arriva alla fermata.
# 136.00: Il passeggero P136 arriva alla fermata.
# 137.00: Il passeggero P137 arriva alla fermata.
# 138.00: Il passeggero P138 arriva alla fermata.
# 139.00: Il passeggero P139 arriva alla fermata.
# 140.00: Il passeggero P140 arriva alla fermata.
# 141.00: Il passeggero P141 arriva alla fermata.
# 142.00: Bus tornato.
# 142.00: Il passeggero P142 arriva alla fermata.
# 142.00: Bus alla fermata in attesa del segnale di partenza.
# 142.00: Il passeggero P111 è salito. Posti occupati: 10
# 142.00: Bus pieno! Il passeggero P111 segnala la partenza.
# 142.00: Il passeggero P112 è salito. Posti occupati: 10
# 142.00: Il passeggero P113 è salito. Posti occupati: 10
# 142.00: Il passeggero P114 è salito. Posti occupati: 10
# 142.00: Il passeggero P115 è salito. Posti occupati: 10
# 142.00: Il passeggero P116 è salito. Posti occupati: 10
# 142.00: Il passeggero P117 è salito. Posti occupati: 10
# 142.00: Il passeggero P118 è salito. Posti occupati: 10
# 142.00: Il passeggero P119 è salito. Posti occupati: 10
# 142.00: Il passeggero P120 è salito. Posti occupati: 10
# 142.00: Segnale ricevuto! Bus parte con 10 passeggeri.
# 143.00: Il passeggero P143 arriva alla fermata.
# 144.00: Il passeggero P144 arriva alla fermata.
# 145.00: Il passeggero P145 arriva alla fermata.
# 146.00: Il passeggero P146 arriva alla fermata.
# 147.00: Il passeggero P147 arriva alla fermata.
# 148.00: Il passeggero P148 arriva alla fermata.
# 149.00: Il passeggero P149 arriva alla fermata.
# 150.00: Il passeggero P150 arriva alla fermata.
# 151.00: Il passeggero P151 arriva alla fermata.
# 152.00: Il passeggero P152 arriva alla fermata.
# 153.00: Il passeggero P153 arriva alla fermata.
# 154.00: Bus tornato.
# 154.00: Il passeggero P154 arriva alla fermata.
# 154.00: Bus alla fermata in attesa del segnale di partenza.
# 154.00: Il passeggero P121 è salito. Posti occupati: 10
# 154.00: Bus pieno! Il passeggero P121 segnala la partenza.
# 154.00: Il passeggero P122 è salito. Posti occupati: 10
# 154.00: Il passeggero P123 è salito. Posti occupati: 10
# 154.00: Il passeggero P124 è salito. Posti occupati: 10
# 154.00: Il passeggero P125 è salito. Posti occupati: 10
# 154.00: Il passeggero P126 è salito. Posti occupati: 10
# 154.00: Il passeggero P127 è salito. Posti occupati: 10
# 154.00: Il passeggero P128 è salito. Posti occupati: 10
# 154.00: Il passeggero P129 è salito. Posti occupati: 10
# 154.00: Il passeggero P130 è salito. Posti occupati: 10
# 154.00: Segnale ricevuto! Bus parte con 10 passeggeri.
# 155.00: Il passeggero P155 arriva alla fermata.
# 156.00: Il passeggero P156 arriva alla fermata.
# 157.00: Il passeggero P157 arriva alla fermata.
# 158.00: Il passeggero P158 arriva alla fermata.
# 159.00: Il passeggero P159 arriva alla fermata.
# 160.00: Il passeggero P160 arriva alla fermata.
# 161.00: Il passeggero P161 arriva alla fermata.
# 162.00: Il passeggero P162 arriva alla fermata.
# 163.00: Il passeggero P163 arriva alla fermata.
# 164.00: Il passeggero P164 arriva alla fermata.
# 165.00: Il passeggero P165 arriva alla fermata.
# 166.00: Bus tornato.
# 166.00: Il passeggero P166 arriva alla fermata.
# 166.00: Bus alla fermata in attesa del segnale di partenza.
# 166.00: Il passeggero P131 è salito. Posti occupati: 10
# 166.00: Bus pieno! Il passeggero P131 segnala la partenza.
# 166.00: Il passeggero P132 è salito. Posti occupati: 10
# 166.00: Il passeggero P133 è salito. Posti occupati: 10
# 166.00: Il passeggero P134 è salito. Posti occupati: 10
# 166.00: Il passeggero P135 è salito. Posti occupati: 10
# 166.00: Il passeggero P136 è salito. Posti occupati: 10
# 166.00: Il passeggero P137 è salito. Posti occupati: 10
# 166.00: Il passeggero P138 è salito. Posti occupati: 10
# 166.00: Il passeggero P139 è salito. Posti occupati: 10
# 166.00: Il passeggero P140 è salito. Posti occupati: 10
# 166.00: Segnale ricevuto! Bus parte con 10 passeggeri.
# 167.00: Il passeggero P167 arriva alla fermata.
# 168.00: Il passeggero P168 arriva alla fermata.
# 169.00: Il passeggero P169 arriva alla fermata.
# 170.00: Il passeggero P170 arriva alla fermata.
# 171.00: Il passeggero P171 arriva alla fermata.
# 172.00: Il passeggero P172 arriva alla fermata.
# 173.00: Il passeggero P173 arriva alla fermata.
# 174.00: Il passeggero P174 arriva alla fermata.
# 175.00: Il passeggero P175 arriva alla fermata.
# 176.00: Il passeggero P176 arriva alla fermata.
# 177.00: Il passeggero P177 arriva alla fermata.
# 178.00: Bus tornato.
# 178.00: Il passeggero P178 arriva alla fermata.
# 178.00: Bus alla fermata in attesa del segnale di partenza.
# 178.00: Il passeggero P141 è salito. Posti occupati: 10
# 178.00: Bus pieno! Il passeggero P141 segnala la partenza.
# 178.00: Il passeggero P142 è salito. Posti occupati: 10
# 178.00: Il passeggero P143 è salito. Posti occupati: 10
# 178.00: Il passeggero P144 è salito. Posti occupati: 10
# 178.00: Il passeggero P145 è salito. Posti occupati: 10
# 178.00: Il passeggero P146 è salito. Posti occupati: 10
# 178.00: Il passeggero P147 è salito. Posti occupati: 10
# 178.00: Il passeggero P148 è salito. Posti occupati: 10
# 178.00: Il passeggero P149 è salito. Posti occupati: 10
# 178.00: Il passeggero P150 è salito. Posti occupati: 10
# 178.00: Segnale ricevuto! Bus parte con 10 passeggeri.
# 179.00: Il passeggero P179 arriva alla fermata.
# 180.00: Il passeggero P180 arriva alla fermata.
# 181.00: Il passeggero P181 arriva alla fermata.
# 182.00: Il passeggero P182 arriva alla fermata.
# 183.00: Il passeggero P183 arriva alla fermata.
# 184.00: Il passeggero P184 arriva alla fermata.
# 185.00: Il passeggero P185 arriva alla fermata.
# 186.00: Il passeggero P186 arriva alla fermata.
# 187.00: Il passeggero P187 arriva alla fermata.
# 188.00: Il passeggero P188 arriva alla fermata.
# 189.00: Il passeggero P189 arriva alla fermata.
# 190.00: Bus tornato.
# 190.00: Il passeggero P190 arriva alla fermata.
# 190.00: Bus alla fermata in attesa del segnale di partenza.
# 190.00: Il passeggero P151 è salito. Posti occupati: 10
# 190.00: Bus pieno! Il passeggero P151 segnala la partenza.
# 190.00: Il passeggero P152 è salito. Posti occupati: 10
# 190.00: Il passeggero P153 è salito. Posti occupati: 10
# 190.00: Il passeggero P154 è salito. Posti occupati: 10
# 190.00: Il passeggero P155 è salito. Posti occupati: 10
# 190.00: Il passeggero P156 è salito. Posti occupati: 10
# 190.00: Il passeggero P157 è salito. Posti occupati: 10
# 190.00: Il passeggero P158 è salito. Posti occupati: 10
# 190.00: Il passeggero P159 è salito. Posti occupati: 10
# 190.00: Il passeggero P160 è salito. Posti occupati: 10
# 190.00: Segnale ricevuto! Bus parte con 10 passeggeri.
# 191.00: Il passeggero P191 arriva alla fermata.
# 192.00: Il passeggero P192 arriva alla fermata.
# 193.00: Il passeggero P193 arriva alla fermata.
# 194.00: Il passeggero P194 arriva alla fermata.
# 195.00: Il passeggero P195 arriva alla fermata.
# 196.00: Il passeggero P196 arriva alla fermata.
# 197.00: Il passeggero P197 arriva alla fermata.
# 198.00: Il passeggero P198 arriva alla fermata.
# 199.00: Il passeggero P199 arriva alla fermata.
